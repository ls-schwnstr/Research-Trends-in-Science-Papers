# %% [markdown]
# # Taxonomy Dictionary
#
# Here, the Category Taxonomy is retrieved from arXiv and saved as a dictionary.

# %%
import requests
from bs4 import BeautifulSoup

def crawl_arxiv_taxonomy(url):
    # Fetch the webpage content
    response = requests.get(url)
    if response.status_code != 200:
        print("Failed to fetch the webpage.")
        return None

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize an empty dictionary to store the taxonomy
    taxonomy = {}

    # Find all subcategories
    subcategory_elements = soup.select('#category_taxonomy_list > div > div > div > div > div > h4')

    # Iterate over subcategories
    for subcategory_element in subcategory_elements:
        main_category_element = subcategory_element.find_previous('h2', class_='accordion-head')
        main_category_name = main_category_element.text.strip()
        
        short_name = subcategory_element.text.strip().split()[0]  # Extracting only the abbreviation
        long_name = subcategory_element.find('span').text.strip('()')

        # Add subcategory to the taxonomy dictionary under the main category
        if main_category_name in taxonomy:
            taxonomy[main_category_name].append({'short_name': short_name, 'long_name': long_name})
        else:
            taxonomy[main_category_name] = [{'short_name': short_name, 'long_name': long_name}]

    return taxonomy

# URL of the arXiv category taxonomy page
url = 'https://arxiv.org/category_taxonomy'

# Crawl the taxonomy
taxonomy_data = crawl_arxiv_taxonomy(url)

# Print the extracted taxonomy
for main_category, subcategories in taxonomy_data.items():
    print("Main Category:", main_category)
    for subcategory in subcategories:
        print("  Short Name:", subcategory['short_name'])
        print("  Long Name:", subcategory['long_name'])
    print()
# Out:
# Main Category: Computer Science
#   Short Name: cs.AI
#   Long Name: Artificial Intelligence
#   Short Name: cs.AR
#   Long Name: Hardware Architecture
#   Short Name: cs.CC
#   Long Name: Computational Complexity
#   Short Name: cs.CE
#   Long Name: Computational Engineering, Finance, and Science
#   Short Name: cs.CG
#   Long Name: Computational Geometry
#   Short Name: cs.CL
#   Long Name: Computation and Language
#   Short Name: cs.CR
#   Long Name: Cryptography and Security
#   Short Name: cs.CV
#   Long Name: Computer Vision and Pattern Recognition
#   Short Name: cs.CY
#   Long Name: Computers and Society
#   Short Name: cs.DB
#   Long Name: Databases
#   Short Name: cs.DC
#   Long Name: Distributed, Parallel, and Cluster Computing
#   Short Name: cs.DL
#   Long Name: Digital Libraries
#   Short Name: cs.DM
#   Long Name: Discrete Mathematics
#   Short Name: cs.DS
#   Long Name: Data Structures and Algorithms
#   Short Name: cs.ET
#   Long Name: Emerging Technologies
#   Short Name: cs.FL
#   Long Name: Formal Languages and Automata Theory
#   Short Name: cs.GL
#   Long Name: General Literature
#   Short Name: cs.GR
#   Long Name: Graphics
#   Short Name: cs.GT
#   Long Name: Computer Science and Game Theory
#   Short Name: cs.HC
#   Long Name: Human-Computer Interaction
#   Short Name: cs.IR
#   Long Name: Information Retrieval
#   Short Name: cs.IT
#   Long Name: Information Theory
#   Short Name: cs.LG
#   Long Name: Machine Learning
#   Short Name: cs.LO
#   Long Name: Logic in Computer Science
#   Short Name: cs.MA
#   Long Name: Multiagent Systems
#   Short Name: cs.MM
#   Long Name: Multimedia
#   Short Name: cs.MS
#   Long Name: Mathematical Software
#   Short Name: cs.NA
#   Long Name: Numerical Analysis
#   Short Name: cs.NE
#   Long Name: Neural and Evolutionary Computing
#   Short Name: cs.NI
#   Long Name: Networking and Internet Architecture
#   Short Name: cs.OH
#   Long Name: Other Computer Science
#   Short Name: cs.OS
#   Long Name: Operating Systems
#   Short Name: cs.PF
#   Long Name: Performance
#   Short Name: cs.PL
#   Long Name: Programming Languages
#   Short Name: cs.RO
#   Long Name: Robotics
#   Short Name: cs.SC
#   Long Name: Symbolic Computation
#   Short Name: cs.SD
#   Long Name: Sound
#   Short Name: cs.SE
#   Long Name: Software Engineering
#   Short Name: cs.SI
#   Long Name: Social and Information Networks
#   Short Name: cs.SY
#   Long Name: Systems and Control
#
# Main Category: Economics
#   Short Name: econ.EM
#   Long Name: Econometrics
#   Short Name: econ.GN
#   Long Name: General Economics
#   Short Name: econ.TH
#   Long Name: Theoretical Economics
#
# Main Category: Electrical Engineering and Systems Science
#   Short Name: eess.AS
#   Long Name: Audio and Speech Processing
#   Short Name: eess.IV
#   Long Name: Image and Video Processing
#   Short Name: eess.SP
#   Long Name: Signal Processing
#   Short Name: eess.SY
#   Long Name: Systems and Control
#
# Main Category: Mathematics
#   Short Name: math.AC
#   Long Name: Commutative Algebra
#   Short Name: math.AG
#   Long Name: Algebraic Geometry
#   Short Name: math.AP
#   Long Name: Analysis of PDEs
#   Short Name: math.AT
#   Long Name: Algebraic Topology
#   Short Name: math.CA
#   Long Name: Classical Analysis and ODEs
#   Short Name: math.CO
#   Long Name: Combinatorics
#   Short Name: math.CT
#   Long Name: Category Theory
#   Short Name: math.CV
#   Long Name: Complex Variables
#   Short Name: math.DG
#   Long Name: Differential Geometry
#   Short Name: math.DS
#   Long Name: Dynamical Systems
#   Short Name: math.FA
#   Long Name: Functional Analysis
#   Short Name: math.GM
#   Long Name: General Mathematics
#   Short Name: math.GN
#   Long Name: General Topology
#   Short Name: math.GR
#   Long Name: Group Theory
#   Short Name: math.GT
#   Long Name: Geometric Topology
#   Short Name: math.HO
#   Long Name: History and Overview
#   Short Name: math.IT
#   Long Name: Information Theory
#   Short Name: math.KT
#   Long Name: K-Theory and Homology
#   Short Name: math.LO
#   Long Name: Logic
#   Short Name: math.MG
#   Long Name: Metric Geometry
#   Short Name: math.MP
#   Long Name: Mathematical Physics
#   Short Name: math.NA
#   Long Name: Numerical Analysis
#   Short Name: math.NT
#   Long Name: Number Theory
#   Short Name: math.OA
#   Long Name: Operator Algebras
#   Short Name: math.OC
#   Long Name: Optimization and Control
#   Short Name: math.PR
#   Long Name: Probability
#   Short Name: math.QA
#   Long Name: Quantum Algebra
#   Short Name: math.RA
#   Long Name: Rings and Algebras
#   Short Name: math.RT
#   Long Name: Representation Theory
#   Short Name: math.SG
#   Long Name: Symplectic Geometry
#   Short Name: math.SP
#   Long Name: Spectral Theory
#   Short Name: math.ST
#   Long Name: Statistics Theory
#
# Main Category: Physics
#   Short Name: astro-ph.CO
#   Long Name: Cosmology and Nongalactic Astrophysics
#   Short Name: astro-ph.EP
#   Long Name: Earth and Planetary Astrophysics
#   Short Name: astro-ph.GA
#   Long Name: Astrophysics of Galaxies
#   Short Name: astro-ph.HE
#   Long Name: High Energy Astrophysical Phenomena
#   Short Name: astro-ph.IM
#   Long Name: Instrumentation and Methods for Astrophysics
#   Short Name: astro-ph.SR
#   Long Name: Solar and Stellar Astrophysics
#   Short Name: cond-mat.dis-nn
#   Long Name: Disordered Systems and Neural Networks
#   Short Name: cond-mat.mes-hall
#   Long Name: Mesoscale and Nanoscale Physics
#   Short Name: cond-mat.mtrl-sci
#   Long Name: Materials Science
#   Short Name: cond-mat.other
#   Long Name: Other Condensed Matter
#   Short Name: cond-mat.quant-gas
#   Long Name: Quantum Gases
#   Short Name: cond-mat.soft
#   Long Name: Soft Condensed Matter
#   Short Name: cond-mat.stat-mech
#   Long Name: Statistical Mechanics
#   Short Name: cond-mat.str-el
#   Long Name: Strongly Correlated Electrons
#   Short Name: cond-mat.supr-con
#   Long Name: Superconductivity
#   Short Name: gr-qc
#   Long Name: General Relativity and Quantum Cosmology
#   Short Name: hep-ex
#   Long Name: High Energy Physics - Experiment
#   Short Name: hep-lat
#   Long Name: High Energy Physics - Lattice
#   Short Name: hep-ph
#   Long Name: High Energy Physics - Phenomenology
#   Short Name: hep-th
#   Long Name: High Energy Physics - Theory
#   Short Name: math-ph
#   Long Name: Mathematical Physics
#   Short Name: nlin.AO
#   Long Name: Adaptation and Self-Organizing Systems
#   Short Name: nlin.CD
#   Long Name: Chaotic Dynamics
#   Short Name: nlin.CG
#   Long Name: Cellular Automata and Lattice Gases
#   Short Name: nlin.PS
#   Long Name: Pattern Formation and Solitons
#   Short Name: nlin.SI
#   Long Name: Exactly Solvable and Integrable Systems
#   Short Name: nucl-ex
#   Long Name: Nuclear Experiment
#   Short Name: nucl-th
#   Long Name: Nuclear Theory
#   Short Name: physics.acc-ph
#   Long Name: Accelerator Physics
#   Short Name: physics.ao-ph
#   Long Name: Atmospheric and Oceanic Physics
#   Short Name: physics.app-ph
#   Long Name: Applied Physics
#   Short Name: physics.atm-clus
#   Long Name: Atomic and Molecular Clusters
#   Short Name: physics.atom-ph
#   Long Name: Atomic Physics
#   Short Name: physics.bio-ph
#   Long Name: Biological Physics
#   Short Name: physics.chem-ph
#   Long Name: Chemical Physics
#   Short Name: physics.class-ph
#   Long Name: Classical Physics
#   Short Name: physics.comp-ph
#   Long Name: Computational Physics
#   Short Name: physics.data-an
#   Long Name: Data Analysis, Statistics and Probability
#   Short Name: physics.ed-ph
#   Long Name: Physics Education
#   Short Name: physics.flu-dyn
#   Long Name: Fluid Dynamics
#   Short Name: physics.gen-ph
#   Long Name: General Physics
#   Short Name: physics.geo-ph
#   Long Name: Geophysics
#   Short Name: physics.hist-ph
#   Long Name: History and Philosophy of Physics
#   Short Name: physics.ins-det
#   Long Name: Instrumentation and Detectors
#   Short Name: physics.med-ph
#   Long Name: Medical Physics
#   Short Name: physics.optics
#   Long Name: Optics
#   Short Name: physics.plasm-ph
#   Long Name: Plasma Physics
#   Short Name: physics.pop-ph
#   Long Name: Popular Physics
#   Short Name: physics.soc-ph
#   Long Name: Physics and Society
#   Short Name: physics.space-ph
#   Long Name: Space Physics
#   Short Name: quant-ph
#   Long Name: Quantum Physics
#
# Main Category: Quantitative Biology
#   Short Name: q-bio.BM
#   Long Name: Biomolecules
#   Short Name: q-bio.CB
#   Long Name: Cell Behavior
#   Short Name: q-bio.GN
#   Long Name: Genomics
#   Short Name: q-bio.MN
#   Long Name: Molecular Networks
#   Short Name: q-bio.NC
#   Long Name: Neurons and Cognition
#   Short Name: q-bio.OT
#   Long Name: Other Quantitative Biology
#   Short Name: q-bio.PE
#   Long Name: Populations and Evolution
#   Short Name: q-bio.QM
#   Long Name: Quantitative Methods
#   Short Name: q-bio.SC
#   Long Name: Subcellular Processes
#   Short Name: q-bio.TO
#   Long Name: Tissues and Organs
#
# Main Category: Quantitative Finance
#   Short Name: q-fin.CP
#   Long Name: Computational Finance
#   Short Name: q-fin.EC
#   Long Name: Economics
#   Short Name: q-fin.GN
#   Long Name: General Finance
#   Short Name: q-fin.MF
#   Long Name: Mathematical Finance
#   Short Name: q-fin.PM
#   Long Name: Portfolio Management
#   Short Name: q-fin.PR
#   Long Name: Pricing of Securities
#   Short Name: q-fin.RM
#   Long Name: Risk Management
#   Short Name: q-fin.ST
#   Long Name: Statistical Finance
#   Short Name: q-fin.TR
#   Long Name: Trading and Market Microstructure
#
# Main Category: Statistics
#   Short Name: stat.AP
#   Long Name: Applications
#   Short Name: stat.CO
#   Long Name: Computation
#   Short Name: stat.ME
#   Long Name: Methodology
#   Short Name: stat.ML
#   Long Name: Machine Learning
#   Short Name: stat.OT
#   Long Name: Other Statistics
#   Short Name: stat.TH
#   Long Name: Statistics Theory

# %%
# Store the dictionary using %store
# %store taxonomy_data
# Out:
# Stored 'taxonomy_data' (dict)
